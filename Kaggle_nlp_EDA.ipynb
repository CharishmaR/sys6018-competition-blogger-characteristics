# %% [markdown]
# Data Exploration

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
file = pd.read_csv("/home/dell/old stuff/train_output5.csv")

# %%
file
# Out:
#         Unnamed: 0  post.id  user.id  gender              topic      sign  \
# 0                0        1    11869    male            Student       Leo
# 1                1        2    11869    male            Student       Leo
# 2                2        3    11869    male            Student       Leo
# 3                3        4    11869    male            Student       Leo
# 4                4        5    16332    male  InvestmentBanking  Aquarius
# 5                5        6    16332    male  InvestmentBanking  Aquarius
# 6                6        7    16332    male  InvestmentBanking  Aquarius
# 7                7        8    16332    male  InvestmentBanking  Aquarius
# 8                8        9    16332    male  InvestmentBanking  Aquarius
# 9                9       10    16332    male  InvestmentBanking  Aquarius
# 10              10       11    16332    male  InvestmentBanking  Aquarius
# 11              11       12    16332    male  InvestmentBanking  Aquarius
# ...

# %%
plt.scatter('age','numofperspronouns', data = file)
plt.ylim(top=3000, bottom = 0) 
plt.show()

# %%
plt.scatter('age','numofnouns', data = file)
plt.ylim(top=7000, bottom = 0) 
plt.show()

# %%
plt.scatter('age','numofdeterminers', data = file)
plt.ylim(top=3000, bottom = 0) 
plt.show()

# %%
plt.scatter('age','numofverbs', data = file)
plt.ylim(top=5000, bottom = 0) 
plt.show()

# %%
file2 = pd.read_csv("/home/dell/old stuff/train_textstat.csv")

# %%
file2
# Out:
#         Unnamed: 0  post.id  user.id  gender              topic      sign  \
# 0                0        1    11869    male            Student       Leo
# 1                1        2    11869    male            Student       Leo
# 2                2        3    11869    male            Student       Leo
# 3                3        4    11869    male            Student       Leo
# 4                4        5    16332    male  InvestmentBanking  Aquarius
# 5                5        6    16332    male  InvestmentBanking  Aquarius
# 6                6        7    16332    male  InvestmentBanking  Aquarius
# 7                7        8    16332    male  InvestmentBanking  Aquarius
# 8                8        9    16332    male  InvestmentBanking  Aquarius
# 9                9       10    16332    male  InvestmentBanking  Aquarius
# 10              10       11    16332    male  InvestmentBanking  Aquarius
# 11              11       12    16332    male  InvestmentBanking  Aquarius
# ...

# %%
plt.scatter('age','numsentences', data = file2)
plt.ylim(top=4000, bottom = 0) 
plt.show()

# %%
plt.scatter('age','numwords', data = file2)
plt.ylim(top=40000, bottom = 0) 
plt.show()

# %%
plt.scatter('age','avgsyllables', data = file2)
#plt.ylim(top=4000, bottom = 0) 
plt.show()

# %%
plt.scatter('age','smog score', data = file2)
plt.ylim(top=50, bottom = 0) 
plt.show()

# %%
plt.scatter('age','linsear score', data = file2)
#plt.ylim(top=50, bottom = 0) 
plt.show()

# %%
plt.scatter('age','dale score', data = file2)
plt.ylim(top=150, bottom = 0) 
plt.show()
